# %%
@'
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import duckdb\n",
    "from faker import Faker\n",
    "\n",
    "print(\"Notebook kernel OK\")\n"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python (.venv)",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": ""
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
'@ | Set-Content -Encoding UTF8 notebooks\01_data_generation.ipynb
# Out:
#   Cell In[2], line 1
#     @'
#      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
import pandas as pd
import duckdb
from faker import Faker

print("Notebook kernel OK")
# Out:
# Notebook kernel OK
